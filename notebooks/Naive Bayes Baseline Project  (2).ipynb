# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cd
# Out:
# /home/rafaelincao

# %%
df_raw = pd.read_csv('gcj2008.csv')
df_raw.head()
# Out:
#    Unnamed: 0  year  round     username   task  solution                file  \
# 0           0  2008  32002  MikeSeibert  24445         0  EndlessKnight.java
# 1           1  2008  32002  MikeSeibert  24444         1        Pockets.java
# 2           2  2008  32002  MikeSeibert  24444         0        Pockets.java
# 3           3  2008  32002  MikeSeibert  24446         0     NoCheating.java
# 4           4  2008  32002     bhamrick  24445         0               D.cpp
#
#                                            full_path  \
# 0  gcj/2008/32002/MikeSeibert/24445/0/extracted/E...
# 1  gcj/2008/32002/MikeSeibert/24444/1/extracted/P...
# 2  gcj/2008/32002/MikeSeibert/24444/0/extracted/P...
# 3  gcj/2008/32002/MikeSeibert/24446/0/extracted/N...
# 4    gcj/2008/32002/bhamrick/24445/0/extracted/D.cpp
#
#                                               flines
# 0  import java.util.Scanner;\n \n public class En...
# 1  import java.util.Scanner;\n \n public class Po...
# 2  import java.util.Scanner;\n \n public class Po...
# 3  import java.util.Scanner;\n \n public class No...
# 4  #include<cstdio>\n #include<cstdlib>\n \n #def...

# %%
df=df_raw.dropna()

# %%
df=df[:1000]
df
# Out:
#      Unnamed: 0  year  round     username   task  solution  \
# 0             0  2008  32002  MikeSeibert  24445         0
# 1             1  2008  32002  MikeSeibert  24444         1
# 2             2  2008  32002  MikeSeibert  24444         0
# 3             3  2008  32002  MikeSeibert  24446         0
# 4             4  2008  32002     bhamrick  24445         0
# ..          ...   ...    ...          ...    ...       ...
# 995         995  2008  32002       Jonasz  24446         1
# 996         996  2008  32002       Jonasz  24446         0
# 997         997  2008  32002     Ragnarok  24445         0
# 998         998  2008  32002     Ragnarok  24443         0
# 999         999  2008  32002     Ragnarok  24446         0
#
#                    file                                          full_path  \
# 0    EndlessKnight.java  gcj/2008/32002/MikeSeibert/24445/0/extracted/E...
# 1          Pockets.java  gcj/2008/32002/MikeSeibert/24444/1/extracted/P...
# 2          Pockets.java  gcj/2008/32002/MikeSeibert/24444/0/extracted/P...
# 3       NoCheating.java  gcj/2008/32002/MikeSeibert/24446/0/extracted/N...
# 4                 D.cpp    gcj/2008/32002/bhamrick/24445/0/extracted/D.cpp
# ..                  ...                                                ...
# 995               C.cpp      gcj/2008/32002/Jonasz/24446/1/extracted/C.cpp
# 996               C.cpp      gcj/2008/32002/Jonasz/24446/0/extracted/C.cpp
# 997         problem.cpp  gcj/2008/32002/Ragnarok/24445/0/extracted/prob...
# 998         problem.cpp  gcj/2008/32002/Ragnarok/24443/0/extracted/prob...
# 999         problem.cpp  gcj/2008/32002/Ragnarok/24446/0/extracted/prob...
#
#                                                 flines
# 0    import java.util.Scanner;\n \n public class En...
# 1    import java.util.Scanner;\n \n public class Po...
# 2    import java.util.Scanner;\n \n public class Po...
# 3    import java.util.Scanner;\n \n public class No...
# 4    #include<cstdio>\n #include<cstdlib>\n \n #def...
# ..                                                 ...
# 995  #include<cstdio>\n #include<algorithm>\n using...
# 996  #include<cstdio>\n #include<algorithm>\n using...
# 997  // BEGIN CUT HERE\n #include "stdafx.h"\n // E...
# 998  // BEGIN CUT HERE\n #include "stdafx.h"\n // E...
# 999  // BEGIN CUT HERE\n #include "stdafx.h"\n // E...
#
# [1000 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
#        338, 338, 338,  94,  94, 307, 307,  66,  66,  14,  14,  14, 332,
#        332, 332,  17,  17,  17,  17, 143, 312, 312, 312, 312, 116, 116,
#        116, 131, 131, 131, 264, 264, 303, 310, 310,  74, 238,  87,  87,
#         87, 296, 296, 296, 296, 296, 330, 313, 313, 201, 201, 201, 201,
#        214, 279,  24,  24, 184, 247, 247, 247, 247, 198, 198,   5,   5,
#          5, 334, 334, 334, 334, 334, 237, 237, 237,  64,  64, 166, 166,
#        287, 287, 192, 192,  41,  41,  41,   8,  34,  22,  22,  22,  22,
#        113, 113, 113, 113, 325, 325, 325, 325, 325, 325, 325, 325, 231,
#        231, 231, 231, 176, 176,  18, 180, 180, 211, 211, 140, 140, 171,
#        171, 171, 335, 335, 208, 208, 208, 208, 208, 208, 345, 345, 333,
#        333, 333, 266, 266, 266, 266, 219, 212, 212,  23, 276, 276,  69,
#         69,  69,  69,  69,  69,  69,  69,  69,  69,  89,  13,  13,  13,
#        324, 324, 124, 124, 124, 124, 261, 261, 274, 274, 274, 274, 274,
#        215, 215, 215,  52,  52, 135, 135, 191, 191, 191, 191, 178, 178,
#        178, 178, 223, 223, 223, 223, 228, 228, 228,  99,  99,  99, 159,
#        159, 159, 159, 159, 159,   0,   0,  45,  45,  45, 103, 103, 327,
#        327, 327, 327, 172, 172, 172, 194, 194, 194, 305, 305,  12, 133,
#        133, 133, 133, 336, 336, 336, 336,  35,  35, 111, 111, 111, 111,
#         90,  90, 286, 286, 343, 343, 343, 117, 117, 117, 117, 117, 341,
#        341, 299, 299,  95,  95,  95, 197, 197, 197, 197, 197, 197, 197,
#        132, 132, 236, 236, 236, 236, 234, 241, 241, 241, 255, 255, 170,
#        170, 170, 170, 251, 251,   2,   2,   2,   2,   2,   2,   2,   2,
#         37,  37,  37,  28,  28,  28,  28, 282, 282, 282, 282, 282, 157,
#        157, 157, 157, 253, 253, 253, 245, 245, 245, 156, 156, 156, 156,
#        156,  16,  16, 278, 278, 260, 260, 260, 260, 260, 260, 151, 151,
#        151, 151, 204, 204, 204, 204, 204, 204, 204, 273, 273, 273, 273,
#        273,  96,  96,  96, 128, 121, 121, 121, 121, 121, 121, 121, 136,
#         58,  58,  58, 145, 145, 145, 145, 145, 235, 235, 235,  84,  84,
#         84,  84,   1, 175, 285, 285, 285,  77,  77,  38, 311, 311,  33,
#         33, 322, 315, 315, 199, 199, 199, 199, 199, 196, 196, 148, 148,
#        148, 148, 189, 189, 189, 189, 189, 189,  78,  78,  78,  67,  67,
#         67,  67,  67,  21,  21,  25,  25,  25, 217, 120, 120, 320, 320,
#        320, 320, 298, 298, 298,  36,  70,  70,  70, 102, 102, 102])

# %%
import numpy as np

from sklearn.model_selection import cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import recall_score

# Feature/Target
X = df["flines"]

# Pipeline vectorizer + Naive Bayes
pipeline_naive_bayes = make_pipeline(
    TfidfVectorizer(), 
    MultinomialNB()
)

# Cross-validation
cv_results = cross_validate(pipeline_naive_bayes, X, y, cv = 5, error_score='raise')
print(cv_results)
average_recall = cv_results["test_score"].mean()
np.round(average_recall,2)

#scoring = ["recall"]
# Out:
# /home/rafaelincao/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# {'fit_time': array([0.35668898, 0.21051693, 0.18301892, 0.19452929, 0.1874187 ]), 'score_time': array([0.03188777, 0.04299617, 0.04951715, 0.04378223, 0.04665303]), 'test_score': array([0.11 , 0.185, 0.25 , 0.235, 0.175])}
# 0.19
